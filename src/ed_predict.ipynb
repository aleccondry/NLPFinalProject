# %%
import utils
from rouge_score import rouge_scorer
import numpy as np
from keras.models import load_model
import pandas as pd
from sklearn.model_selection import train_test_split
import random
import os

# %%
# setup ROUGE scorer and tokenizer
ROUGE_METRICS = ['rouge1', 'rouge2', 'rougeL', 'rougeLsum']
scorer = rouge_scorer.RougeScorer(ROUGE_METRICS, use_stemmer=True)

# Load trained encoder-decoder model
encoder_model = load_model('../trained_models/encoder_model.h5', compile=False)
decoder_model = load_model('../trained_models/decoder_model.h5', compile=False)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
post_pre = pd.read_csv('../data/ed_cleaned_data.csv')
post_pre = post_pre.loc[:, ~post_pre.columns.str.contains('^Unnamed')]
post_pre = post_pre.fillna("")

#Train and test split
x_tr, x_val, y_tr, y_val = train_test_split(
    np.array(post_pre["text"]),
    np.array(post_pre["summary"]),
    test_size=0.1,
    random_state=0,
    shuffle=False,
)

max_text_len = 100
#This will cap the max length of the summaries produced to be 10 words long
max_summary_len = 10

#Tokenizer for articles
art_tokenizer, x_tr, x_val = utils.build_tokenizer(x_tr, x_val, max_text_len)
#Tokenizer for headlines
head_tokenizer, y_tr, y_val = utils.build_tokenizer(y_tr, y_val, max_summary_len)

# Size of vocabulary (+1 for padding token)
art_voc = art_tokenizer.num_words + 1
head_voc = head_tokenizer.num_words + 1

reverse_target_word_index = head_tokenizer.index_word
reverse_source_word_index = art_tokenizer.index_word
target_word_index = head_tokenizer.word_index
# Out:
# % of rare words in vocabulary:  45.7757871354066
# % of rare words in vocabulary:  48.27797149324035

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors
    (e_out, e_h, e_c) = encoder_model.predict(input_seq, verbose=False)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Populate first word with start word
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        #Predicts value from decoder
        (output_tokens, h, c) = decoder_model.predict([target_seq] + [e_out, e_h, e_c], verbose=False)

        #Gets a random sample from the highest probability indices 
        sampled_token_index = random.choice(np.argsort(output_tokens[0, -1, :])[3:5])
        #Gets the word associated with sampled token
        sampled_token = reverse_target_word_index[sampled_token_index]

        if sampled_token != 'eostok':
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find the stop word.
        if sampled_token == 'eostok' or len(decoded_sentence.split()) >= max_summary_len - 1:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        (e_h, e_c) = (h, c)

    return decoded_sentence

# %%
def seq2summary(input_seq):
    """
    Converts sequence of tokenized values to its respective article.
    """
    newString = ''
    for i in input_seq:
        if i != 0 and i != target_word_index['sostok'] and i != target_word_index['eostok']:
            newString = newString + reverse_target_word_index[i] + ' '
    return newString

def seq2text(input_seq):
    """
    Converts sequence of tokenized values to its respective headline.

    """
    newString = ''
    for i in input_seq:
        if i != 0:
            newString = newString + reverse_source_word_index[i] + ' '
    return newString

# %%
ah = {} # GET TESTING HEADLINES FOR EACH DATASET
ph = {} # GET ED PREDICTED HEADLINES FOR EACH DATASET

if 'results_ed.csv' in os.listdir('../data/'):
    preds_df = pd.read_csv('../data/results_ed.csv')
    preds = {'predicted headline': preds_df['predicted headline'].tolist(), 'actual headline': preds_df['actual headline'].tolist()}
else:
    preds = {'predicted headline': [], 'actual headline': []}
    
    
i = len(preds['predicted headline'])

#Loops through 1000 articles to predict their headline then load it into csv file
while i <= 1000:
    actual_headline = seq2summary(y_tr[i])
    predicted_headline = decode_sequence(x_tr[i].reshape(1, max_text_len))
    ah[i] = actual_headline
    ph[i] = predicted_headline
    preds['predicted headline'].append(predicted_headline)
    preds['actual headline'].append(actual_headline)
    print(f'{i}:')
    print(f'\tactual: {actual_headline}')
    print(f'\tpredic: {predicted_headline}')
    if i % 50 == 0 and i != 0:
        preds_df = pd.DataFrame.from_dict(preds, orient='columns')
        preds_df.to_csv('../data/results_ed.csv')
    i += 1
# Out:
# 951:
# 	actual: start twitter suspended an autistic man who tweets pictures after copyright complaints end
# 	predic:  legalize adviser face navarro phase ufc off’ ‘brexit broke robertson accounts pakistani alleging advertising films tips manchin wider maher
# 952:
# 	actual: start hispanics in the us fast facts end
# 	predic:  legalize ford japanese ford your your francis teams pinkerton shock money kentucky 2014 across routine globalists also manslaughter ‘to
# 953:
# 	actual: start box office hur’ bombs ’suicide squad’ stays on top end
# 	predic:  drought elie eating afd live criminals money video nuns greg race’ marriages marines houston hackers weiner creepy devices ’racist’
# 954:
# 	actual: start sources dennis hastert cover up for sexual misconduct end
# 	predic:  drought elie eating afd encourages switzerland bears nra bloomberg hackers circle rebel economists detroit advisers reportedly slain an firefighter
# 955:
# 	actual: start dirt bike riders beat up driver on california freeway end
# 	predic:  legalize ford rain rail means expects platform kate executions global warplane chemical president’ replaces atlanta filter caroline waiting 270
# 956:
# 	actual: start french inmate unlocks others fire set end
# 	predic:  drought elie eating video alligator retailers underwater sessions picked 20 92 gut duterte ready steven polling credible last heaven
# 957:
# 	actual: start the most successful stores in retail have one thing in common they’re ugly end
# 	predic:  drought elie hollande he’ll garden prior successful underage connected 2 foreigners chinese mateen deport name shifts 91 super mental
# 958:
# 	actual: start hillary clinton calls 31 million breitbart readers ’racist’ end
# 	predic:  legalize ford japanese trevor 40 soda flip tirade seized next arabic species harley ’could dominate everyone brazil’s ages triggers
# 959:
# 	actual: start cnn 10 february 14 2017 end
# 	predic:  reduce strong chases dow dow serena gaffney fl nine viola outlets vetoes time recorded officials apocalypse tracks holy barkley
# 960:
# 	actual: start republican party megyn kelly titanic your wednesday briefing end
# 	predic:  drought elie restraint wake unprecedented challenging jennifer sessions poly begin kong’s game keys aging resign philadelphia 2011 2011 considered
# 961:
# 	actual: start mike pence donald trump ’loves his family and he loves this country’ end
# 	predic:  drought elie eating afd encourages consecutive higher interrupted football practices suffer ring hockey russell league rant wwii lowest comfortable
# 962:
# 	actual: start u s starts deploying thaad antimissile system in south korea after tests end
# 	predic:  drought elie eating afd live appeals sanders lectures double unfair best vote best live churches setting fear racist’ websites
# 963:
# 	actual: start police move in on arena bomber’s ’network end
# 	predic:  legalize ford rain music joss benefits allow diet delegate delegate dwyane describes delegate nc firm cathedral caitlyn starbucks carly
# 964:
# 	actual: start watch chair hurling brawl breaks out in nyc seafood end
# 	predic:  drought practices marathon notes noonan recruiting fbi legally medicaid discrimination frank turner ’absolutely dark makeup persian code review panic
# 965:
# 	actual: start this little device could improve your home wi fi and it’s on sale today end
# 	predic:  drought practices sony o’donnell swiss aide rages deserves nationalists nationalists arena third moment geller street’s ground bridge whedon cream
# 966:
# 	actual: start explores violence youth with twist end
# 	predic:  reduce counting wrestling legalize reynolds nude analyst global persian boxing keith erupts stole indonesia condoleezza ’deep bribery 48 compare
# 967:
# 	actual: start florida’s largest county to comply with trump’s sanctuary crackdown end
# 	predic:  drought elie eating afd encourages switzerland bears harvard lgbtq spencer suddenly executives stealing palm tourism via revolutionary illinois suspect
# 968:
# 	actual: start gary johnson on charitable donations ’almost end
# 	predic:  drought elie eating afd live criminals money video nuns awaits medal now crushed cardinal punished borders olympians experience danish
# 969:
# 	actual: start trump administration orders tougher screening of visa applicants end
# 	predic:  legalize adviser face navarro bishop colleges premiums fiscal jew lure bill’s clinch bill’s propose venue gate needs professor miami
# 970:
# 	actual: start pokemon go takes state department briefing end
# 	predic:  legalize ford rain music joss fury gold torn faculty faculty curt portraits ’to dossier rich relatives possibility ross shopping
# 971:
# 	actual: start mexican national charged for alleged assault on ice agent end
# 	predic:  drought practices sony o’donnell swiss aide statement beyond orders material milo 12 prisoner political inciting judge mouth tesla disaster
# 972:
# 	actual: start tightened security worldwide for new year’s eve end
# 	predic:  legalize adviser face a facebook check afd peter schwarzenegger wilbur violent jet hundreds ’go spelling 87 exam moms reduce
# 973:
# 	actual: start a song for bill de blasio sounds sour note for end
# 	predic:  reduce counting prior globalist lets dr dr durant kkk ocean korea’s six pregnancy ships ‘it’s hopes false persecution hour
# 974:
# 	actual: start michelle obama calls out at campaign stop for clinton end
# 	predic:  legalize ford japanese trevor 40 soda flip latest thanksgiving twitter violations ovation ai looking barbra barbra relatives flees elementary
# 975:
# 	actual: start trump’s campaign style lost in end
# 	predic:  drought practices sony o’donnell meat 500 vatican aside pinkerton ’alt mayer bad’ apartment thru shared until secretive door squad
# 976:
# 	actual: start twin falls pol savages family of refugee rape victim on facebook end
# 	predic:  drought elie 7 coalition gender flooding lies’ questions greatest westminster greatest control he’s homes nominated clearance amtrak breitbart they’re
# 977:
# 	actual: start south korea election moon jae in declared winner end
# 	predic:  legalize ford japanese trevor practices super rail wing’ global assad’s freeman tuesday ms community dominance e3 abusing otto student
# 978:
# 	actual: start a night with bill cosby it’s complicated end
# 	predic:  legalize rasmussen shaken expectations zones november bound bound citizen veteran theft criticizing abortions ’go coolest anderson tribune judgment thing’
# 979:
# 	actual: start bud an for equity reaches hall of fame end
# 	predic:  reduce genital like report drought killers assange post’s g mario henry guru leftists handing balloon populism scott giant vets
# 980:
# 	actual: start donald trump claims media is ’poisoning the minds’ of voters end
# 	predic:  legalize ford japanese lauderdale van practices ’right carlos trade unhappy mortgage later ass inquiry street’ ’right soldiers qz8501 ’islam
# 981:
# 	actual: start new electoral map projection shows big lead for hillary clinton but it’s shrinking end
# 	predic:  legalize ford reduce celebrations beck’s quotes migrant journey miracle elie mook southeast dems’ cutting degree justin prediction policy exchanges
# 982:
# 	actual: start john mccain fundraiser arrested in major drug bust end
# 	predic:  drought elie eating afd live criminals money beck else fine beck architecture ideology ralph emails maria to daughters shortage
# 983:
# 	actual: start rick empty diner strategy end
# 	predic:  legalize laden facebook jet accusers iran unprecedented wages common guard seen flashback holiday hotel jewish blair backs trash nominates
# 984:
# 	actual: start f b i says it needs hackers to keep up with tech companies end
# 	predic:  legalize ford reduce counting counting gorsuch’s real stance ebola binge shutting such baffles f 79 library library spangled alleging
# 985:
# 	actual: start sjws clash over ’transphobic’ hashtag end
# 	predic:  drought practices marathon notes noonan ghostbusters soaring gabbana desert ’stop inequality bankrupt ‘i’m safety lionel ’come endorses out’ defiant
# 986:
# 	actual: start trump got ’bad from the super bowl end
# 	predic:  drought practices marathon operatives notes emma pot visa 75 from 12 clearance win’ drop stirs harry spox ’offensive’ statue
# 987:
# 	actual: start ai weiwei lin verdict exposes the of china’s legal system end
# 	predic:  legalize ford reduce celebrations fellow rise walking little photos foreigners foreigners stretch london clearance enemies muslim alligator child aided
# 988:
# 	actual: start ingraham mcconnell ok with attacking trump because establishment’s ’about power’ end
# 	predic:  legalize ford japanese trevor 40 street’ ferrell migrant anxious drones beheads extreme landmark refuse macron opening opening flynn’s journalist
# 989:
# 	actual: start hillary clinton warns against treating donald trump as candidate end
# 	predic:  drought practices sony sweeps pentagon legalize rain syrians part react promises refugees outcome parade cory ’america ’far bono lawsuits
# 990:
# 	actual: start equality’ marchers push for progress on lgbt rights end
# 	predic:  reduce genital like report correctness class russia’s ideology is ghost gives rhetoric threatens play focuses prisons temporary massachusetts constituents
# 991:
# 	actual: start fans call to after import ban end
# 	predic:  legalize adviser unfair swiss hold fellow order nerve kaine manchester taiwan backs hours weight gorsuch happened tense apocalypse we’ve
# 992:
# 	actual: start border patrol agents bust child sexual predator murderer end
# 	predic:  drought practices sony sweeps pentagon arctic partnership nightmare rapist’ 800 ’serious future richest causes assailant reviews clemson ’nothing entered
# 993:
# 	actual: start sheriff david clarke hillary is ’a straight up cop hater’ end
# 	predic:  drought practices marathon notes noonan recruiting fbi drawing chicago near brain budget 69 architecture collar upends wwii players bee
# 994:
# 	actual: start how tom cruise from moving plane end
# 	predic:  reduce counting prior globalist lets homes day covering cleared comedy autism violations rally dominance endorsement round ralph kong’s seized
# 995:
# 	actual: start what shot 41 amazing sports photos end
# 	predic:  drought practices sony o’donnell swiss aide rages pulls rain hampshire istanbul miranda injury earth’s student’s researchers trigger golden mlk
# 996:
# 	actual: start theresa may rejects second scottish referendum before brexit end
# 	predic:  legalize ford japanese trevor practices super master olympic blunt cause ’america rest works fiery declared app answer stop sudden
# 997:
# 	actual: start fbi investigating possible hack of democratic party staffer cell phones end
# 	predic:  drought practices sony o’donnell swiss palin persecution sweeps brazilian video awesome video ’major architecture me no crucial ’clinton starting
# 998:
# 	actual: start clinton and trump campaigns are buzzing about the race for the cabinet end
# 	predic:  drought elie hollande e eating shuts evolution rejecting arriving rejecting adviser hip plant camp short aim practices christopher honors
# 999:
# 	actual: start cnn 10 january 11 2017 end
# 	predic:  legalize ford rain rail scotus friendly ups prosecution lost comfortable firefighter offender education california’s cases soars olympic prediction successfully
# 1000:
# 	actual: start van jones trump ’a super predator running for president’ end
# 	predic:  drought practices sony o’donnell meat 500 spreading guy ecuador soros pokemon ignoring m permit ’hate alarm backed america’ rifle
