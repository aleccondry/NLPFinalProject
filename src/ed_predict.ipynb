# %%
import utils
from rouge_score import rouge_scorer
import numpy as np
from keras.models import load_model
import pandas as pd
from sklearn.model_selection import train_test_split
import random
import os

# %%
# setup ROUGE scorer and tokenizer
ROUGE_METRICS = ['rouge1', 'rouge2', 'rougeL', 'rougeLsum']
scorer = rouge_scorer.RougeScorer(ROUGE_METRICS, use_stemmer=True)

# Load trained encoder-decoder model
encoder_model = load_model('../trained_models/encoder_model.h5', compile=False)
decoder_model = load_model('../trained_models/decoder_model.h5', compile=False)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
post_pre = pd.read_csv('../data/ed_cleaned_data.csv')
post_pre = post_pre.loc[:, ~post_pre.columns.str.contains('^Unnamed')]
post_pre = post_pre.fillna("")

#Train and test split
x_tr, x_val, y_tr, y_val = train_test_split(
    np.array(post_pre["text"]),
    np.array(post_pre["summary"]),
    test_size=0.1,
    random_state=0,
    shuffle=False,
)

max_text_len = 100
#This will cap the max length of the summaries produced to be 10 words long
max_summary_len = 10

#Tokenizer for articles
art_tokenizer, x_tr, x_val = utils.build_tokenizer(x_tr, x_val, max_text_len)
#Tokenizer for headlines
head_tokenizer, y_tr, y_val = utils.build_tokenizer(y_tr, y_val, max_summary_len)

# Size of vocabulary (+1 for padding token)
art_voc = art_tokenizer.num_words + 1
head_voc = head_tokenizer.num_words + 1

reverse_target_word_index = head_tokenizer.index_word
reverse_source_word_index = art_tokenizer.index_word
target_word_index = head_tokenizer.word_index
# Out:
# % of rare words in vocabulary:  45.7757871354066
# % of rare words in vocabulary:  48.27797149324035

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors
    (e_out, e_h, e_c) = encoder_model.predict(input_seq, verbose=False)

    # Generate empty target sequence of length 1
    target_seq = np.zeros((1, 1))

    # Populate first word with start word
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''

    while not stop_condition:
        #Predicts value from decoder
        (output_tokens, h, c) = decoder_model.predict([target_seq] + [e_out, e_h, e_c], verbose=False)

        #Gets a random sample from the highest probability indices 
        sampled_token_index = 0
        while sampled_token_index == 0:
            sampled_token_index = random.choice(np.argsort(output_tokens[0, -1, :])[0:5])
        
        #Gets the word associated with sampled token
        sampled_token = reverse_target_word_index[sampled_token_index]

        if sampled_token != 'eostok':
            decoded_sentence += ' ' + sampled_token

        # Exit condition: either hit max length or find the stop word.
        if sampled_token == 'eostok' or len(decoded_sentence.split()) >= max_summary_len - 1:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        (e_h, e_c) = (h, c)

    return decoded_sentence

# %%
def seq2summary(input_seq):
    """
    Converts sequence of tokenized values to its respective article.
    """
    newString = ''
    for i in input_seq:
        if i != 0 and i != target_word_index['sostok'] and i != target_word_index['eostok']:
            newString = newString + reverse_target_word_index[i] + ' '
    return newString

def seq2text(input_seq):
    """
    Converts sequence of tokenized values to its respective headline.

    """
    newString = ''
    for i in input_seq:
        if i != 0:
            newString = newString + reverse_source_word_index[i] + ' '
    return newString

# %%
ah = {} # GET TESTING HEADLINES FOR EACH DATASET
ph = {} # GET ED PREDICTED HEADLINES FOR EACH DATASET

if 'results_ed.csv' in os.listdir('../data/'):
    preds_df = pd.read_csv('../data/results_ed.csv')
    preds = {'predicted headline': preds_df['predicted headline'].tolist(), 'actual headline': preds_df['actual headline'].tolist()}
else:
    preds = {'predicted headline': [], 'actual headline': []}
    
    
i = len(preds['predicted headline'])

#Loops through 1000 articles to predict their headline then load it into csv file
while i <= 1000:
    actual_headline = seq2summary(y_tr[i])[6:-4]
    predicted_headline = decode_sequence(x_tr[i].reshape(1, max_text_len))
    ah[i] = actual_headline
    ph[i] = predicted_headline
    preds['predicted headline'].append(predicted_headline)
    preds['actual headline'].append(actual_headline[6:-4]) # Remove start and end from actual headline for results
    print(f'{i}:')
    print(f'\tactual: {actual_headline}')
    print(f'\tpredic: {predicted_headline}')
    if i % 50 == 0 and i != 0:
        preds_df = pd.DataFrame.from_dict(preds, orient='columns')
        preds_df.to_csv('../data/results_ed.csv')
    i += 1
# Out:
# 0:
# 	actual: start hillary offered nothing to nevertrump conservatives end
# 	predic:  krauthammer
# 1:
# 	actual: an unprecedented change to the national security council end
# 	predic:  whoopi 84 84 preserve ampt york service’ undo turley
# 2:
# 	actual: risky flight from south pole arrives in chile end
# 	predic:  krauthammer service’ install sostok flashback supporter’s turley rasmussen politico
# 3:
# 	actual: start trump tells reporters work just ask israel’ end
# 	predic:  flashback ‘for abolish ‘for thrones’ kneel turley bottom’ sostok
# 4:
# 	actual: why law enforcement will like justice neil gorsuch end
# 	predic:  hamilton’ country’ korea semitic turley turley turley service’ fabric
# 5:
# 	actual: start harry belafonte don’t die’ end
# 	predic:  krauthammer interaction preserve sostok whoopi sostok krauthammer turley hamilton’
# 6:
# 	actual: start breitbart news daily trump addresses congress end
# 	predic:  delingpole imminent’ solve turley rehear turley bottom’ fracture kent
# 7:
# 	actual: start migrants settled in hotel hosting furry convention end
# 	predic:  krauthammer ‘for service’ turley hampshire’s sostok tancredo ‘for krauthammer
# 8:
# 	actual: over pet care helps explain human health spending end
# 	predic:  krauthammer ’legitimate’ krauthammer aol turley sostok flashback supporter’s yorkers
# 9:
# 	actual: start evan mcmullin president donald trump is enemy end
# 	predic:  politico country’ undo undo thrones’ thrones’ undo korea’s 2013
# 10:
# 	actual: debate expected to be rare draw in age end
# 	predic:  krauthammer turley undo turley turley sostok flashback mud’ homestretch
# 11:
# 	actual: start bill ackman is getting end
# 	predic:  krauthammer ‘for service’ turley turley sostok hamilton’ ‘for sostok
# 12:
# 	actual: apple is planning for the next 000 years end
# 	predic:  krauthammer sostok tancredo inside’ service’ sostok flashback turley impose
# 13:
# 	actual: in return to tour at farmers insurance open end
# 	predic:  krauthammer interaction service’ service’ impose turley turley resettle turley
# 14:
# 	actual: in sports everybody will be talking about today end
# 	predic:  rasmussen lite microaggressions microaggressions whoopi mailing flashback krauthammer polygraph
# 15:
# 	actual: republican delegates for cheering for gay people’s protection end
# 	predic:  flashback service’ solve sostok hamilton’ least sostok krauthammer leans
# 16:
# 	actual: up home at the edge of the world end
# 	predic:  whoopi service’ sostok flashback ‘for turley krauthammer service’ sostok
# 17:
# 	actual: start watch celebrities beg congress to donald trump end
# 	predic:  hamilton’ kool preserve sostok hamilton’ service’ fracture ’secret service’
# 18:
# 	actual: in areas with zika w h o suggests end
# 	predic:  hamilton’ service’ preserve ‘for ‘for cair’s yorker end’ service’
# 19:
# 	actual: lynch obama can’t give pardon to dreamers en end
# 	predic:  whoopi preserve solve sostok krauthammer service’ sostok flashback lags
# 20:
# 	actual: rabbi ‘there is new reality’ following truck terror end
# 	predic:  flashback ammo undo hampshire francisco sostok whoopi least acknowledges
# 21:
# 	actual: mike pence donald trump your tuesday evening briefing end
# 	predic:  krauthammer service’ reinstate resolve sostok krauthammer oversee oversee undo
# 22:
# 	actual: start mary ellen portraits from high school proms end
# 	predic:  tancredo liberties impose sostok sostok whoopi excoriates turley whoopi
# 23:
# 	actual: start 2016 livewire republican national convention kicks off end
# 	predic:  krauthammer turley solve service’ rehear turley sostok hamilton’ kent
# 24:
# 	actual: balloon pilot didn’t see power lines investigators think end
# 	predic:  hamilton’ ‘for turley sostok rasmussen ‘for deeply sostok flashback
# 25:
# 	actual: optimism obama hails clinton as his political heir end
# 	predic:  whoopi undo turley sostok whoopi airspace sostok whoopi turley
# 26:
# 	actual: women’s march on washington opens contentious about race end
# 	predic:  flashback lite service’ terminate firebombing service’ service’ service’ turley
# 27:
# 	actual: what cities could look like in 10 years end
# 	predic:  flashback turley sostok flashback turley turley whoopi sostok rasmussen
# 28:
# 	actual: bbc presenter signs off on flagship debate programme end
# 	predic:  hamilton’ ’classified’ service’ sostok rasmussen turley ‘for sostok flashback
# 29:
# 	actual: been since donald trump attacked someone on twitter end
# 	predic:  hamilton’ sostok tancredo service’ service’ turley afdi service’ turley
# 30:
# 	actual: matt damon defends sean penn’s el chapo interview end
# 	predic:  whoopi prohibition semite supremacy’ korea sostok whoopi sostok tancredo
# 31:
# 	actual: release images of bomber moments before arena blast end
# 	predic:  krauthammer ‘for sostok whoopi ’classified’ users’ york’s service’ sostok
# 32:
# 	actual: start civil war re for photographer end
# 	predic:  hamilton’ ‘for turley turley turley schiff genuine bottom’ service’
# 33:
# 	actual: booted for remarks about mexicans jews and chinese end
# 	predic:  whoopi jong clinton’ york’s service’ sostok hamilton’ sostok whoopi
# 34:
# 	actual: state says he’ll block trump’s supreme court nominee end
# 	predic:  flashback solve preserve specific afdi hydrogen ampt stripper mapping
# 35:
# 	actual: start coca cola sends message with label free end
# 	predic:  flashback gravis service’ firebombing turley service’ turley retrieve usmc
# 36:
# 	actual: start the democrat national department of justice end
# 	predic:  krauthammer sostok whoopi undo sostok flashback sostok flashback ’hurting
# 37:
# 	actual: probe into valeant’s former ceo raises big questions end
# 	predic:  hamilton’ newsman service’ ‘for service’ turley resettle tran service’
# 38:
# 	actual: paris trump just dodged 2 5 trillion bullet end
# 	predic:  flashback introduced reassure service’ decorate turley virgil krauthammer cede
# 39:
# 	actual: day refugee pause from failed middle eastern countries end
# 	predic:  krauthammer ’classified’ undo service’ terminate centrist sostok krauthammer usmc
# 40:
# 	actual: in syria chemical attack ’i saw the explosion end
# 	predic:  krauthammer valley turley times’s sostok hamilton’ introduced excoriates krauthammer
# 41:
# 	actual: one of the job interview questions about money end
# 	predic:  flashback meetup impose turley sostok krauthammer sostok tancredo macklemore
# 42:
# 	actual: nigel farage vs david cameron in brexit ’debate end
# 	predic:  flashback treads sostok hamilton’ ‘for service’ sostok flashback turley
# 43:
# 	actual: start road to 270 cnn’s new election map end
# 	predic:  krauthammer service’ undo ’beauty’ cede turley paramount service’ sostok
# 44:
# 	actual: they see in trump they just have to end
# 	predic:  hamilton’ steamrolled solve sostok krauthammer sostok whoopi realize service’
# 45:
# 	actual: what would change your mind about president trump end
# 	predic:  krauthammer ’legitimate’ preserve service’ service’ sostok hamilton’ service’ service’
# 46:
# 	actual: numbers on bullets to fight chicago gun violence end
# 	predic:  whoopi supremacy preserve service’ service’ turley turley sostok whoopi
# 47:
# 	actual: match featuring man flying is flag was ’racist end
# 	predic:  flashback ‘for service’ turley turley krauthammer sostok whoopi turley
# 48:
# 	actual: synagogue smeared with feces in attack on chanukah end
# 	predic:  tancredo liberties survive’ service’ ‘for sostok tancredo ’perfectly usmc
# 49:
# 	actual: start again obama with clinton is rapist’ protester end
# 	predic:  flashback pullback 84 ampt jong service’ ces sostok whoopi
# 50:
# 	actual: b charts economic course politics complicate the picture end
# 	predic:  krauthammer leans install sostok tancredo ‘for whoopi ‘for whoopi
# 51:
# 	actual: medal after relay teammate found guilty of doping end
# 	predic:  whoopi service’ satisfy turley 1995 turley service’ election’s election’s
# 52:
# 	actual: that has been terrifying wall street for years end
# 	predic:  hamilton’ leans terminate service’ sostok krauthammer sostok flashback sostok
# 53:
# 	actual: people who feel younger at heart live longer end
# 	predic:  whoopi sostok whoopi turley flashback sostok krauthammer turley krauthammer
# 54:
# 	actual: trump on clinton guards take their guns away end
# 	predic:  whoopi turley lure taunting service’ turley paramount strickland anglo
# 55:
# 	actual: used car in an age of widespread recalls end
# 	predic:  flashback ‘for turley turley service’ turley understanding cincinnati service’
# 56:
# 	actual: moran trump inauguration speech had ‘anti semitic overtones’ end
# 	predic:  krauthammer interaction preserve turley service’ sostok flashback service’ ’secret
# 57:
# 	actual: start the right wing supreme court that wasn’t end
# 	predic:  whoopi tighter semite service’ turley service’ sostok flashback mud’
# 58:
# 	actual: start in nation here’s who gets my vote end
# 	predic:  rasmussen turley terminate turley zealand’s turley election’s ’looking ’looking
# 59:
# 	actual: rejects ca high speed rail 15 billion loan end
# 	predic:  krauthammer chemistry’ 84 service’ turley turley turley accomplish sostok
# 60:
# 	actual: start isis claims responsibility for kuwait mosque attack end
# 	predic:  hamilton’ carolina politico undo sostok whoopi excoriates rasmussen politico
# 61:
# 	actual: bridge killer all 12 suspects released without charge end
# 	predic:  rasmussen turley preserve turley sostok flashback service’ york delingpole
# 62:
# 	actual: read classified 28 pages of 9 11 report end
# 	predic:  hamilton’ solve turley understanding terminate sostok flashback service’ service’
# 63:
# 	actual: austria rejects far right presidential candidate norbert hofer end
# 	predic:  krauthammer flourished frame frame terminate yorkers cede anglo anglo
# 64:
# 	actual: vowing to squeeze businesses trump has tactics challenged end
# 	predic:  hamilton’ testify preserve ampt turley atone service’ strickland turley
# 65:
# 	actual: start jeb bush’s pre announcement strategy explained end
# 	predic:  delingpole stunt’ solve sostok thrones’ solve relocating q4 service’
# 66:
# 	actual: msnbc airs ’f word’ during sanders supporters debate end
# 	predic:  krauthammer ‘for kristallnacht assimilate guatemala service’ kent orleans strickland
# 67:
# 	actual: version of wikipedia here’s what it looks like end
# 	predic:  whoopi ‘for leans terminate ‘for service’ turley rasmussen rasmussen
# 68:
# 	actual: ’an embarrassment to breitbart’ for criticizing facebook meeting end
# 	predic:  krauthammer old’s evening sostok undo ’important’ undo turley preserve
# 69:
# 	actual: start california official voter fraud claims ’dangerous end
# 	predic:  rasmussen mascot solve sostok thrones’ least service’ paramount sostok
# 70:
# 	actual: right to trust trump to ’lead our party’ end
# 	predic:  krauthammer turley recruit turley rehear sostok tancredo onion whoopi
# 71:
# 	actual: win by telling people not to be angry end
# 	predic:  whoopi saddam preserve turley dover turley kent kent preserve
# 72:
# 	actual: dropping health vote trump swallowed need for showdown end
# 	predic:  tancredo joker solve service’ cede 2025 terminate cede thrones’
# 73:
# 	actual: populist supporters abandon trump at home and abroad end
# 	predic:  politico mascot detect sostok whoopi sostok delingpole leans retain
# 74:
# 	actual: video claims to show paris attackers threatens britain end
# 	predic:  rasmussen ‘for sostok rasmussen service’ undo hampshire rasmussen krauthammer
# 75:
# 	actual: kelly slams obama’s policies proclaims to protect america end
# 	predic:  flashback newsman solve sostok thrones’ serve decorate afdi afdi
# 76:
# 	actual: oscar nominees have these gifts in the bag end
# 	predic:  tancredo interaction sostok whoopi ‘for firebombing turley service’ sostok
# 77:
# 	actual: start cnn student news august 15 2016 end
# 	predic:  hamilton’ ‘for ’quiet ’tone ‘for terminate service’ sostok hamilton’
# 78:
# 	actual: start democrats we need this new direction end
# 	predic:  whoopi relocating undo sostok hamilton’ whoopi usmc usmc usmc
# 79:
# 	actual: repeal of online privacy protections means for you end
# 	predic:  hamilton’ newsman sostok whoopi least sostok flashback service’ impose
# 80:
# 	actual: borders must stay open despite deadly terror attacks end
# 	predic:  krauthammer old’s turley deeply hampshire bottom’ service’ turley ’bimbo’
# 81:
# 	actual: uzbekistan bans video games that security political stability’ end
# 	predic:  flashback old’s frame service’ service’ sostok krauthammer sostok hamilton’
# 82:
# 	actual: 5 things to watch in georgia special election end
# 	predic:  flashback upended 84 ’whiteness’ quo’ sostok hamilton’ least sostok
# 83:
# 	actual: agrees to broad change for troubled police dept end
# 	predic:  whoopi service’ reassure turley yorkers centrist sostok krauthammer recently
# 84:
# 	actual: getting tighter in the most crucial swing states end
# 	predic:  delingpole treads semite semite paramount sostok pew yorkers solve
# 85:
# 	actual: start the real issue for distractinglysexy female scientists end
# 	predic:  whoopi ‘for turley service’ turley sostok krauthammer least service’
# 86:
# 	actual: with steve bannon that media is the party end
# 	predic:  rasmussen 84 ampt ‘for service’ terminate centrist firebombing turley
# 87:
# 	actual: there’s better way to fight off morning breath end
# 	predic:  krauthammer service’ turley decorate sostok krauthammer turley krauthammer understanding
# 88:
# 	actual: with anti gamergate developer wu to attack breitbart end
# 	predic:  whoopi hydrogen preserve semite sostok krauthammer sostok flashback turley
# 89:
# 	actual: and rain may turnout in pro remain london end
# 	predic:  whoopi ’classified’ deeply turley deeply leans service’ sostok hamilton’
# 90:
# 	actual: start bars long big part of the boehner end
# 	predic:  tancredo ‘for service’ 2025 aol aol brakes negotiate ’bimbo’
# 91:
# 	actual: start new photos show pluto still taking shape end
# 	predic:  flashback disapprove survive’ ‘for turley know’ schiff pew negotiate
# 92:
# 	actual: park indicted for bribery and abuse of power end
# 	predic:  politico year’s krauthammer turley krauthammer ’remain jamie decent retain
# 93:
# 	actual: depaul college republicans response of campus security ’utterly end
# 	predic:  krauthammer koppel preserve ‘for sostok krauthammer sostok rasmussen krauthammer
# 94:
# 	actual: montana congressman is trump’s choice for interior secretary end
# 	predic:  krauthammer turley 84 ’whiteness’ service’ antidote undo ‘for iggy
# 95:
# 	actual: an unlikely backup option for their quarterback emergency end
# 	predic:  flashback francis quo’ service’ service’ turley sostok flashback leans
# 96:
# 	actual: start transgender bathroom solution and more end
# 	predic:  flashback newsman turley sostok whoopi sostok flashback inside’ sostok
# 97:
# 	actual: start us utility alleged russian malware on laptop end
# 	predic:  flashback lite semite turley turley service’ absurdly absurdly anglo
# 98:
# 	actual: breitbart news daily burgess owens ann coulter dinesh end
# 	predic:  whoopi sostok whoopi semite korea korea anglo 84 mapping
# 99:
# 	actual: start bullfighter gored to death in end
# 	predic:  krauthammer
# 100:
# 	actual: border cop accused of aiding drug cartel operations end
# 	predic:  hamilton’ service’ recruit restriction hampshire krauthammer dunham falwell falwell
# 101:
# 	actual: start lebron james endorses hillary clinton for president end
# 	predic:  krauthammer treads atone kristallnacht service’ service’ sostok tancredo anglo
# 102:
# 	actual: start what shot 39 amazing sports photos end
# 	predic:  politico hampshire grappling sostok whoopi sostok hamilton’ turley rasmussen
# 103:
# 	actual: start mexican journalist killed in sinaloa end
# 	predic:  whoopi turley flashback ‘for turley stevie p recruit yorker
# 104:
# 	actual: american way of winning the war against disease end
# 	predic:  tancredo turley turley service’ service’ turley service’ service’ turley
# 105:
# 	actual: start here comes la nina end
# 	predic:  flashback francis ‘for ‘for sostok krauthammer logging resettle service’
# 106:
# 	actual: start planned parenthood celebrates century of eugenics end
# 	predic:  krauthammer evening hamilton’ turley korea turley turley sostok flashback
# 107:
# 	actual: of syria gas attack recount ‘a cruel scene’ end
# 	predic:  flashback supporter’s sostok politico ‘for realize service’ sostok krauthammer
# 108:
# 	actual: meet pope francis after priest murdered by jihadists end
# 	predic:  krauthammer mascot preserve bottom’ turley service’ yorker sostok hamilton’
# 109:
# 	actual: start utah police investigate brutal attack hate crimes end
# 	predic:  krauthammer sostok flashback service’ aol turley sostok flashback turley
# 110:
# 	actual: half of america we at sears hate you end
# 	predic:  krauthammer koppel solve sostok hamilton’ korea korea sostok flashback
# 111:
# 	actual: on if hillary clinton will hold press conference end
# 	predic:  flashback murky undo sostok flashback skilled verify hamilton’ service’
# 112:
# 	actual: horror movies the companies operate in the red end
# 	predic:  hamilton’ ‘for turley centrist service’ turley zumwalt kneel toby
# 113:
# 	actual: rahami’s father says he told f b i end
# 	predic:  tancredo ‘for survive’ ‘for service’ turley sostok hamilton’ quo’
# 114:
# 	actual: in favor of new constitution preliminary results show end
# 	predic:  hamilton’ service’ 2025 2025 sostok flashback turley retain retain
# 115:
# 	actual: arrested development’ returns to netflix for fifth season end
# 	predic:  hamilton’ ’classified’ ’classified’ ‘for sostok whoopi service’ firebombing woodward
# 116:
# 	actual: tears for u s army convoy in europe end
# 	predic:  rasmussen ‘for service’ turley service’ turley gopro strickland sostok
# 117:
# 	actual: walgreens cuts ties to blood testing company theranos end
# 	predic:  hamilton’ newsman turley sostok krauthammer turley krauthammer impose service’
# 118:
# 	actual: start jeb ‘i’m going to win this nomination’ end
# 	predic:  politico kayak undo fracture ’misgendering’ centrist logging logging radicalisation
# 119:
# 	actual: father says the ’new immigrants make america great end
# 	predic:  hamilton’ turley undo arabia bottom’ bottom’ bottom’ sostok hamilton’
# 120:
# 	actual: start the most amazing videos of the week end
# 	predic:  krauthammer sostok politico excoriates krauthammer turley rasmussen rasmussen flashback
# 121:
# 	actual: migrant crime and violence soars in german states end
# 	predic:  tancredo turley resolve service’ ‘for hampshire sostok hamilton’ rasmussen
# 122:
# 	actual: start mulvaney democrats on border wall end
# 	predic:  krauthammer atone recruit ‘for sostok whoopi recruit decorate usmc
# 123:
# 	actual: drama about muslim rape gang doesn’t mention islam end
# 	predic:  whoopi inside’ terminate frame service’ service’ turley sostok whoopi
# 124:
# 	actual: confirms more gitmo transfers before obama leaves office end
# 	predic:  rasmussen bernardino solve 84 preserve sostok flashback sostok hamilton’
# 125:
# 	actual: the iphone and plus that makes the phone end
# 	predic:  whoopi mascot impose sostok tancredo turley krauthammer impose understanding
# 126:
# 	actual: daily pat buchanan on trump’s first 100 days end
# 	predic:  whoopi service’ kristallnacht fracture kent thrones’ anglo zealand ampt
# 127:
# 	actual: hugs and hard labor on an indiana farm end
# 	predic:  flashback ‘for sostok flashback sostok hamilton’ service’ turley rasmussen
# 128:
# 	actual: there aren’t more police shootings just more coverage end
# 	predic:  whoopi turley sostok whoopi service’ turley krauthammer taiwan’s broaden
# 129:
# 	actual: idea that playing with toy guns is cool end
# 	predic:  tancredo old’s service’ frame service’ service’ tran sostok tancredo
# 130:
# 	actual: start goodbye for good to black sabbath end
# 	predic:  tancredo ‘for ‘for turley service’ turley understanding schiff schiff
# 131:
# 	actual: start who won the debate end
# 	predic:  delingpole demolished solve paramount turley windy bottom’ paramount aol
# 132:
# 	actual: request seeks 2 6 billion for border infrastructure end
# 	predic:  krauthammer testify recruit ‘for cede logging centrist sostok tancredo
# 133:
# 	actual: start why the left hates mother teresa of end
# 	predic:  krauthammer ‘for turley turley sostok hamilton’ service’ aol service’
# 134:
# 	actual: start romney backs trump’s choice for education secretary end
# 	predic:  krauthammer preserve resolve service’ maiden sostok whoopi rebrand rebrand
# 135:
# 	actual: the american who accidentally became chinese movie star end
# 	predic:  tancredo sostok flashback ’classified’ ‘for sostok whoopi service’ usmc
# 136:
# 	actual: using cell phone to film up woman’s skirt end
# 	predic:  flashback sostok tancredo service’ sostok whoopi service’ realize turley
# 137:
# 	actual: anti science claims dog green party’s jill stein end
# 	predic:  hamilton’ relocating ces firebombing aol strickland strickland brakes solemn
# 138:
# 	actual: start mark zuckerberg and the new progressive end
# 	predic:  tancredo old’s briefing ‘for sostok hamilton’ korea turley ’forget
# 139:
# 	actual: donald trump invite roils pro israel aipac conference end
# 	predic:  krauthammer ‘for marry terminate sostok whoopi turley whoopi sostok
# 140:
# 	actual: start and kate end
# 	predic:  krauthammer ‘for sostok politico sostok politico turley krauthammer service’
# 141:
# 	actual: trump appoints top deputies more white house staff end
# 	predic:  rasmussen undo abolish turley turley turley turley turley accomplish
# 142:
# 	actual: deserted golf courses reveal new normal in america end
# 	predic:  whoopi leans impose service’ sostok whoopi turley ’secret sostok
# 143:
# 	actual: star studded guest list for obama birthday bash end
# 	predic:  flashback advancing service’ korea rouge turley korea’s york’s windy
# 144:
# 	actual: start f 35 set to make its debut end
# 	predic:  hamilton’ service’ sostok krauthammer ‘for service’ service’ sostok tancredo
# 145:
# 	actual: questioned for five hours on suspicions of corruption end
# 	predic:  flashback lite semite hampshire ‘for hampshire yorker preserve retain
# 146:
# 	actual: start hill gop skeptical of trump’s tax announcement end
# 	predic:  delingpole ‘for ensemble service’ sostok beleaguered realize rebrand sostok
# 147:
# 	actual: has something than cars to sell its story end
# 	predic:  tancredo janitor sostok tancredo service’ korea semitism turley jamie
# 148:
# 	actual: new york prison break inmate gave mitchell painting end
# 	predic:  krauthammer
# 149:
# 	actual: to say obamacare was ’a burden to people’ end
# 	predic:  flashback yourself’ solve ‘for rehear service’ turley kent accidental
# 150:
# 	actual: start russia’s space program in crisis end
# 	predic:  hamilton’ turley deeply service’ service’ sostok whoopi turley whoopi
# 151:
# 	actual: wrong on us taking back returning isis fighters end
# 	predic:  krauthammer preserve recruit 2025 beleaguered yorkers accomplish mapping paramount
# 152:
# 	actual: start burr give law enforcement tools they need end
# 	predic:  rasmussen ampt recruit afdi sostok hamilton’ turley ’diablo retain
# 153:
# 	actual: angeles charter school advocates win school board majority end
# 	predic:  tancredo ‘for turley service’ service’ bottom’ turley bottom’ leans
# 154:
# 	actual: by diversity of volunteers at trump h q end
# 	predic:  whoopi newsman terminate turley turley resettle bottom’ ontario traits
# 155:
# 	actual: airbnb how to make it work for you end
# 	predic:  hamilton’ ‘for turley centrist sostok whoopi turley sostok krauthammer
# 156:
# 	actual: flies to scotland to tend to business interests end
# 	predic:  tancredo tighter hijack sostok krauthammer sostok flashback skilled smother
# 157:
# 	actual: start nbc’s allen dems desperate hero in obama’ end
# 	predic:  tancredo koppel undo service’ sostok flashback sostok hamilton’ least
# 158:
# 	actual: meet the most valuable startups in the us end
# 	predic:  flashback newsman ‘for service’ ‘for turley understanding whoopi sostok
# 159:
# 	actual: start the world’s most dangerous fashion show end
# 	predic:  rasmussen ‘for ‘for turley snl’ turley rasmussen rasmussen sostok
# 160:
# 	actual: start congressman dies after cancer battle end
# 	predic:  whoopi start 1970s solve turley turley service’ bottom’ aol
# 161:
# 	actual: start military cuba plane crash kills troops end
# 	predic:  whoopi carolina hamilton’ sostok krauthammer excoriates flashback whoopi turley
# 162:
# 	actual: joe furious after donald trump praises stephen miller end
# 	predic:  hamilton’ saddam semite hydrogen ‘for sostok solve least service’
# 163:
# 	actual: outcry forces obama’s hand uncensored orlando transcripts released end
# 	predic:  rasmussen hampshire solve service’ bottom’ understanding sidestep hampshire hampshire
# 164:
# 	actual: elizabeth warren delivers anti trump tirade at dnc end
# 	predic:  krauthammer treads undo turley ensemble service’ kent tampa radicalisation
# 165:
# 	actual: olympics phelps upset judo snub and bitter goalie end
# 	predic:  flashback backward’ cede sostok politico sostok whoopi sostok whoopi
# 166:
# 	actual: an olive branch to local governments its data end
# 	predic:  whoopi newsman turley turley service’ resettle resettle centrist turley
# 167:
# 	actual: for universal voter registration calls out gop opponents end
# 	predic:  rasmussen 84 e3 semite ’beauty’ sostok tancredo onion smother
# 168:
# 	actual: lobbying ban defeat isis plan national security council end
# 	predic:  flashback ’essentially abolish turley thrones’ ampt bottom’ recently bottom’
# 169:
# 	actual: dare fellow republicans to vote against obamacare repeal end
# 	predic:  krauthammer
# 170:
# 	actual: silence officer testifies about killing of walter scott end
# 	predic:  flashback service’ bullsh flashback mafia’ flashback sostok krauthammer least
# 171:
# 	actual: matter wants to push socialist sanders even left end
# 	predic:  flashback newsman solve ‘for rehear service’ anglo bottom’ anglo
# 172:
# 	actual: graphic cartel violence kills 10 near texas border end
# 	predic:  flashback sostok politico ’quiet service’ dunham service’ flashback rasmussen
# 173:
# 	actual: start inmate’s teacher alleges rape prison negligence end
# 	predic:  hamilton’ sostok whoopi service’ turley service’ turley snl’ turley
# 174:
# 	actual: of le pen in post debate snap poll end
# 	predic:  hamilton’ yourself’ korea semitism korea sostok krauthammer service’ sostok
# 175:
# 	actual: wasserman schultz will resign after the democratic convention end
# 	predic:  whoopi undo undo turley rehear matter’s korea korea’s accomplish
# 176:
# 	actual: montana dwight clark ’the with bit of twist end
# 	predic:  whoopi jong service’ terminate service’ sostok hamilton’ ‘for sostok
# 177:
# 	actual: start new hampshire state of mind end
# 	predic:  hamilton’ service’ sostok hamilton’ turley service’ service’ service’ turley
# 178:
# 	actual: start dakota access pipeline police remove protesters end
# 	predic:  hamilton’ service’ terminate service’ sostok hamilton’ service’ aol haley’s
# 179:
# 	actual: start the review disappointing step end
# 	predic:  tancredo turley ‘for sostok flashback ’legitimate’ service’ sostok tancredo
# 180:
# 	actual: worker allegedly filmed sex acts with underage migrants end
# 	predic:  krauthammer sostok krauthammer sostok krauthammer repels turley flashback turley
# 181:
# 	actual: economists still opposed to trump’s economic nationalist program end
# 	predic:  krauthammer unfazed preserve service’ cede service’ arranged firebombing resettle
# 182:
# 	actual: rodriguez is at peace as he walks away end
# 	predic:  flashback meetup turley turley sostok whoopi turley sostok whoopi
# 183:
# 	actual: start trump gives colorful new year’s eve speech end
# 	predic:  whoopi relocating abolish sostok whoopi least firebombing flashback turley
# 184:
# 	actual: couple beaten with canes for violating sharia law end
# 	predic:  tancredo ‘for turley decorate francisco bottom’ francisco sostok flashback
# 185:
# 	actual: start dem rep trump’s is in question’ end
# 	predic:  whoopi preserve preserve fracture hydrogen kent thrones’ cram resettle
# 186:
# 	actual: start huge volcano fills skies end
# 	predic:  hamilton’ turley sostok whoopi ’classified’ impose turley service’ turley
# 187:
# 	actual: start german rock festival resumes terror threat cleared end
# 	predic:  whoopi ‘for service’ bottom’ bottom’ service’ service’ 1990 turley
# 188:
# 	actual: start fitness expert greg dies end
# 	predic:  krauthammer
# 189:
# 	actual: seek leads in july blast in central park end
# 	predic:  krauthammer sostok politico ‘for sostok krauthammer waking install service’
# 190:
# 	actual: arrest man acting during easter mass in nice end
# 	predic:  hamilton’ valley service’ hampshire hampshire p ampt jong gravis
# 191:
# 	actual: today hijab emerging as ’symbol of resistance and end
# 	predic:  flashback kool recruit service’ hydrogen bottom’ turley thrones’ sostok
# 192:
# 	actual: start breitbart news sunday milo in da house end
# 	predic:  tancredo turley solve service’ ’beauty’ ‘for ‘for ’forget turley
# 193:
# 	actual: hedge fund horror show as valeant gets slaughtered end
# 	predic:  flashback newsman ‘for sostok whoopi least fordham resettle service’
# 194:
# 	actual: facebook runs up against german hate speech laws end
# 	predic:  whoopi yourself’ solve sostok flashback ’desperate install sostok krauthammer
# 195:
# 	actual: cnn’s tapper trump worse and more than obama end
# 	predic:  flashback proliferation negotiate fracture turley sostok flashback supporter’s restrict
# 196:
# 	actual: harbor visit called first looks more like fourth end
# 	predic:  rasmussen newsman preserve hydrogen service’ firebombing turley service’ turley
# 197:
# 	actual: trump tees up for golf with tiger woods end
# 	predic:  whoopi 84 semite liberties service’ square’ sostok rasmussen politico
# 198:
# 	actual: ‘we’re going to enforce our immigration laws guys end
# 	predic:  krauthammer preserve recruit kent ampt thrones’ windy york’s york’s
# 199:
# 	actual: start deadly rocks ukraine city of end
# 	predic:  rasmussen supporter’s sostok politico turley politico flashback rasmussen hamilton’
# 200:
# 	actual: percent of brigade combat teams unprepared to fight end
# 	predic:  flashback defied preserve service’ sostok whoopi leans turley hamilton’
# 201:
# 	actual: trump won the gop debate by losing it end
# 	predic:  krauthammer sostok delingpole chemistry’ recruit turley mapping fracture paramount
# 202:
# 	actual: office tweets in middle of tom price hearing end
# 	predic:  flashback treads screw service’ usmc sostok krauthammer excoriates krauthammer
# 203:
# 	actual: matter is the worst slogan i’ve ever heard’ end
# 	predic:  flashback supporter’s jong matter’s korea korea service’ ct yorkers
# 204:
# 	actual: will not attend white house super bowl celebration end
# 	predic:  tancredo treads turley sostok tancredo service’ decorate ‘for usmc
# 205:
# 	actual: start watch live donald trump in grand mi end
# 	predic:  whoopi 1995 preserve preserve preserve logging sostok whoopi least
# 206:
# 	actual: win in political correctness crusade on high school end
# 	predic:  flashback ‘for ‘for turley ‘for turley sostok rasmussen snl’
# 207:
# 	actual: biggest question regarding the trump travel ban case end
# 	predic:  hamilton’ mascot preserve sostok hamilton’ leans turley whoopi sostok
# 208:
# 	actual: diver wins olympic silver then gets podium proposal end
# 	predic:  hamilton’ ‘for turley deeply turley rasmussen krauthammer turley ’looking
# 209:
# 	actual: the boss ‘the only girl in the building’ end
# 	predic:  whoopi service’ sostok tancredo sostok hamilton’ ’classified’ turley impartial’
# 210:
# 	actual: start macron against arresting and deporting radical islamists end
# 	predic:  whoopi country’ country’ carolina turley swamp’ thrones’ diego delingpole
# 211:
# 	actual: start a reporter his steps through trump country end
# 	predic:  krauthammer leans reassure ‘for service’ turley centrist service’ service’
# 212:
# 	actual: to do ’something pretty positive’ in north korea end
# 	predic:  krauthammer orleans service’ sostok whoopi sostok flashback service’ sostok
# 213:
# 	actual: milo would hold style’ white house press briefings end
# 	predic:  tancredo sostok flashback supporter’s atone impose service’ turley krauthammer
# 214:
# 	actual: has resigned following his controversial gender diversity comments end
# 	predic:  whoopi donald undo hampshire turley service’ sostok hamilton’ turley
# 215:
# 	actual: start donald trump’s conservative foreign policy end
# 	predic:  whoopi backward’ semite semite logging 2025 service’ service’ service’
# 216:
# 	actual: start storm flights arctic blast on the way end
# 	predic:  krauthammer ‘for turley sostok krauthammer punish service’ ’forget turley
# 217:
# 	actual: what trump victory could mean for lgbt americans end
# 	predic:  krauthammer sostok hamilton’ ‘for sostok solve flashback krauthammer smother
# 218:
# 	actual: start veep debate in 140 characters and more end
# 	predic:  flashback golan golan turley pew whoopi service’ excoriates rasmussen
# 219:
# 	actual: deploys aircraft carrier to disputed south china sea end
# 	predic:  flashback york’s recruit yorkers preserve ampt supremacy’ iggy parenthood
# 220:
# 	actual: bbc to refer to ’honour killings’ as ’murder end
# 	predic:  whoopi ‘for turley centrist carolina bottom’ undo diego sostok
# 221:
# 	actual: start murphy trump shouldn’t get classified info end
# 	predic:  delingpole table’ preserve 2025 fracture anglo synthetic thrones’ stripper
# 222:
# 	actual: mccarthy plays tree hugging in super bowl commercial end
# 	predic:  whoopi ‘for sostok hamilton’ sostok tancredo imminent’ turley sostok
# 223:
# 	actual: muslim faith helped me cope with anthony weiner end
# 	predic:  krauthammer sostok krauthammer sostok flashback sostok politico service’ negotiate
# 224:
# 	actual: reinstate travel ban dealing trump another legal loss end
# 	predic:  rasmussen orleans detect zealand’s hampshire hydrogen undo undo nominate
# 225:
# 	actual: trump dinner details to the new york times end
# 	predic:  whoopi 84 preserve e3 thrones’ blackrock thrones’ turley accomplish
# 226:
# 	actual: it’s official clinton swamps trump in popular vote end
# 	predic:  hamilton’ grievance marry grievance service’ service’ sostok flashback airspace
# 227:
# 	actual: start suspect under investigation in champs elysees attack end
# 	predic:  matthews orleans york’s hampshire york’s hampshire york’s york’s remember’
# 228:
# 	actual: pen attack on emmanuel macron in french debate end
# 	predic:  krauthammer old’s beleaguered service’ service’ afdi afdi sostok tancredo
# 229:
# 	actual: attacks unrest grows in migrant heavy french suburbs end
# 	predic:  tancredo turley survive’ turley orleans service’ orleans hampshire rasmussen
# 230:
# 	actual: how much will city election change ferguson missouri end
# 	predic:  flashback ‘for turley turley service’ turley service’ turley turley
# 231:
# 	actual: sarah palin kaepernick take knee over this one end
# 	predic:  hamilton’ turley service’ turley turley sostok krauthammer turley krauthammer
# 232:
# 	actual: start chuck schumer trump opposition leader end
# 	predic:  flashback relocating recruit turley aol aol anglo anglo thrones’
# 233:
# 	actual: let iran take israel and the jews hostage end
# 	predic:  flashback ‘for undo turley atone turley service’ sostok whoopi
# 234:
# 	actual: ’muslim ban’ exempts eighty seven percent of muslims end
# 	predic:  whoopi mascot preserve turley sostok whoopi ’classified’ service’ sostok
# 235:
# 	actual: start what it’s like to document miracle end
# 	predic:  rasmussen newsman ‘for sostok whoopi least frum krauthammer sostok
# 236:
# 	actual: evening briefing bernie sanders donald trump boko haram end
# 	predic:  whoopi ucf preserve decorate service’ service’ myrtle gravis recruit
# 237:
# 	actual: start lindsey graham retires from air force end
# 	predic:  hamilton’ radioactive semite 2025 service’ quo’ undo antidote solve
# 238:
# 	actual: muslims offer mixed response to new mohammed cover end
# 	predic:  rasmussen ammo ‘for turley turley rasmussen flashback service’ service’
# 239:
# 	actual: start the fall and rise of lawyers end
# 	predic:  krauthammer newsman service’ ’classified’ ’classified’ turley schiff turley ’forget
# 240:
# 	actual: hillary clinton’s judgment on benghazi attack in 2012 end
# 	predic:  krauthammer install terminate parenthood parenthood parenthood restriction anglo turley
# 241:
# 	actual: start alan dershowitz scalia’s ‘most fundamental end
# 	predic:  flashback newsman jong clinton’ solve turley sostok tancredo whoopi
# 242:
# 	actual: before ‘hamilton’ brouhaha theater was anything but polite end
# 	predic:  tancredo newsman ’classified’ service’ ‘for sostok flashback sostok krauthammer
# 243:
# 	actual: start in ankara celebrations for erdogan mask turkish end
# 	predic:  flashback nor service’ sostok whoopi ‘for sostok krauthammer testify
# 244:
# 	actual: to hold north korea accountable ’with our actions end
# 	predic:  krauthammer interaction solve sostok solve service’ service’ usmc ‘for
# 245:
# 	actual: president trump restart the drone war in pakistan end
# 	predic:  rasmussen ‘for service’ sostok flashback ‘for sostok rasmussen ‘for
# 246:
# 	actual: start a suburban experiment aims for free energy end
# 	predic:  krauthammer ‘for service’ turley ’classified’ turley service’ turley sostok
# 247:
# 	actual: start hillary clinton donald trump ’gun lobby’ end
# 	predic:  whoopi undo turley preserve service’ anglo sostok krauthammer krauthammer
# 248:
# 	actual: newt gingrich defends trump’s star of david tweet end
# 	predic:  delingpole continent undo service’ service’ afdi 84 recruit anglo
# 249:
# 	actual: the case for more government and higher taxes end
# 	predic:  hamilton’ prohibition preserve sostok flashback turley sostok krauthammer whoopi
# 250:
# 	actual: aliens caught in months in single texas sector end
# 	predic:  whoopi valley sostok krauthammer dunham ‘for service’ turley flashback
# 251:
# 	actual: ’dead clinton blew huge of cash in california end
# 	predic:  krauthammer sostok delingpole service’ semitism service’ turley accomplish strickland
# 252:
# 	actual: playing in the n f l at 38 end
# 	predic:  tancredo newsman service’ sostok hamilton’ sostok whoopi sostok whoopi
# 253:
# 	actual: putin help to block u s embassy move end
# 	predic:  whoopi hampshire preserve ampt pen peru preserve turley unlock
# 254:
# 	actual: school advocate trump has tapped as education secretary end
# 	predic:  flashback newsman preserve service’ turley sostok whoopi firebombing sostok
# 255:
# 	actual: currently screening social media of all syrian refugees end
# 	predic:  rasmussen 84 solve turley service’ service’ glover sostok krauthammer
# 256:
# 	actual: start kim jong nam investigation north korean released end
# 	predic:  hamilton’ valley recruit turley krauthammer turley krauthammer carolina negotiate
# 257:
# 	actual: 2 of society should help the other 98 end
# 	predic:  hamilton’ ‘for sostok flashback physically sostok flashback prohibition service’
# 258:
# 	actual: cart of food stamp household lots of soda end
# 	predic:  flashback service’ service’ turley sostok tancredo turley flashback matthews
# 259:
# 	actual: start wimbledon djokovic federer win end
# 	predic:  flashback ‘for turley sostok flashback ’classified’ turley krauthammer infect
# 260:
# 	actual: geert wilders donald trump scotland your wednesday briefing end
# 	predic:  whoopi honest’ sostok rasmussen ‘for pew krauthammer krauthammer polygraph
# 261:
# 	actual: fights erupted at pro trump rally in california end
# 	predic:  whoopi flourished recruit sostok tancredo krauthammer sostok whoopi least
# 262:
# 	actual: cnn host campbell brown to lead news team end
# 	predic:  krauthammer old’s turley turley ’forget turley sostok rasmussen cincinnati
# 263:
# 	actual: criticized for praising fidel castro as ‘remarkable leader’ end
# 	predic:  flashback francis semite korea sostok whoopi leans service’ sostok
# 264:
# 	actual: start report migrant children will german school system end
# 	predic:  krauthammer ‘for sostok whoopi service’ disparage sostok hamilton’ leans
# 265:
# 	actual: start harrison ford makes first public appearance end
# 	predic:  flashback ‘for sostok krauthammer service’ impose ‘for service’ service’
# 266:
# 	actual: no obama hillary clinton is unfit for office end
# 	predic:  flashback sostok whoopi semite semite turley belk anglo turley
# 267:
# 	actual: under armour ceo praises trump’s business vision and end
# 	predic:  tancredo old’s turley terminate firebombing service’ bottom’ sostok whoopi
# 268:
# 	actual: bill cosby’s trial jurors to return on friday end
# 	predic:  rasmussen newsman kristallnacht turley ‘for chemistry’ krauthammer spades deeply
# 269:
# 	actual: start summer travel and the zika virus end
# 	predic:  tancredo ‘for service’ sostok hamilton’ turley krauthammer sostok whoopi
# 270:
# 	actual: has weak support going into 2018 gop primary end
# 	predic:  whoopi joker solve matter’s 2025 sostok dear ‘for recruit
# 271:
# 	actual: start oregon dead injured shooting suspect in custody end
# 	predic:  hamilton’ service’ recruit sostok krauthammer service’ krauthammer ‘for krauthammer
# 272:
# 	actual: to bow to lgbt demands to punish christians end
# 	predic:  hamilton’ chemistry’ negotiate turley service’ turley resettle service’ service’
# 273:
# 	actual: withdraws from consideration to replace comey at fbi end
# 	predic:  whoopi solve preserve sostok whoopi recruit election’s sostok delingpole
# 274:
# 	actual: start in read the lefty inauguration day tweets end
# 	predic:  hamilton’ prohibition recruit sostok flashback ’legitimate’ service’ firebombing service’
# 275:
# 	actual: intervention in american election was no one off end
# 	predic:  whoopi ’even recruit ‘for profound sostok rasmussen sostok whoopi
# 276:
# 	actual: trump golden state warriors your friday evening briefing end
# 	predic:  rasmussen sostok krauthammer ’illegal’ oversee oversee resolve screw service’
# 277:
# 	actual: islamic state using female terrorists more and more end
# 	predic:  whoopi service’ satisfy sostok krauthammer realize usmc chemistry’ hamilton’
# 278:
# 	actual: man carrying human head stabs grocery store employee end
# 	predic:  hamilton’ turley redemption sostok tancredo turley flashback service’ yorker
# 279:
# 	actual: clinton it’s painful’ to run against donald trump end
# 	predic:  krauthammer service’ undo turley ’forget sostok krauthammer fracture smother
# 280:
# 	actual: start will uber make your job opinion end
# 	predic:  hamilton’ ammo ’classified’ service’ sostok flashback ’millions service’ service’
# 281:
# 	actual: snap is said to have worked on drone end
# 	predic:  flashback ‘for service’ service’ sostok flashback service’ resettle turley
# 282:
# 	actual: start 13 things only lagos entrepreneur will understand end
# 	predic:  rasmussen turley sostok krauthammer turley flashback service’ service’ turley
# 283:
# 	actual: start donald trump ‘i disavow’ alt right groups end
# 	predic:  whoopi turley solve turley turley centrist service’ service’ turley
# 284:
# 	actual: protest groups conflict over race in santa cruz end
# 	predic:  whoopi flourished solve service’ grievance mud’ bottom’ service’ koreans
# 285:
# 	actual: police officers torn from patrol car during riot end
# 	predic:  tancredo sostok krauthammer service’ aol sostok tancredo turley hamilton’
# 286:
# 	actual: start a is taking place in financial technology end
# 	predic:  krauthammer ‘for ‘for service’ service’ turley service’ terminate service’
# 287:
# 	actual: win if republicans come together to defeat hillary end
# 	predic:  hamilton’ newsman preserve fracture fracture afdi turley satirical turley
# 288:
# 	actual: old girl comes out to her mormon congregation end
# 	predic:  hamilton’ sostok politico ‘for turley flashback sostok flashback junks
# 289:
# 	actual: ryan’s plans stopped cold by trump cruz insurgency end
# 	predic:  hamilton’ preserve verify dover mogadishu kent anglo orleans radicalisation
# 290:
# 	actual: start canadian parliament passes controversial islamophobia motion end
# 	predic:  tancredo ‘for turley service’ bottom’ service’ service’ sostok whoopi
# 291:
# 	actual: groups launch ads in indiana against the donald end
# 	predic:  krauthammer service’ impose sostok hamilton’ mafia’ ‘for anglo 1968
# 292:
# 	actual: smashes expectations here’s what you need to know end
# 	predic:  hamilton’ turley service’ turley sostok hamilton’ turley rasmussen rasmussen
# 293:
# 	actual: look at me 24 selfies of the week end
# 	predic:  rasmussen grappling zombie polygraph turley flashback flashback krauthammer nevertrumper
# 294:
# 	actual: years to fix obamacare give me 10 minutes end
# 	predic:  hamilton’ sostok flashback supporter’s service’ korea turley impose service’
# 295:
# 	actual: for allegedly shooting at police officer in georgia end
# 	predic:  whoopi valley turley mafia’ service’ hampshire flashback rasmussen rasmussen
# 296:
# 	actual: start interview developer discusses creating western in end
# 	predic:  krauthammer sostok tancredo ‘for turley service’ service’ service’ service’
# 297:
# 	actual: crews reveals how he stays in insane shape end
# 	predic:  krauthammer turley turley sostok krauthammer turley sostok tancredo excoriates
# 298:
# 	actual: info on gunman after rare white wolf dies end
# 	predic:  politico disapprove preserve chemistry’ rasmussen rasmussen rasmussen tombstone 2013
# 299:
# 	actual: start anti terror police thames tourist boat hijacking end
# 	predic:  tancredo turley preserve sostok krauthammer excoriates hamilton’ ’perfectly sostok
# 300:
# 	actual: trump’s secret weapon letters of love and revenge end
# 	predic:  flashback ’important’ undo ‘for service’ service’ sostok krauthammer turley
# 301:
# 	actual: where’s your courage now that you’re free agent end
# 	predic:  tancredo chemistry’ detect korea sostok krauthammer turley cincinnati yorkers
# 302:
# 	actual: of bay area’s millennial residents want to leave end
# 	predic:  tancredo chemistry’ preserve service’ aol service’ sostok hamilton’ turley
# 303:
# 	actual: start berta family seeks justice end
# 	predic:  rasmussen sostok whoopi service’ sostok whoopi ‘for sostok politico
# 304:
# 	actual: start perfect league record ended end
# 	predic:  rasmussen newsman turley service’ turley flashback sostok hamilton’ turley
# 305:
# 	actual: start jennifer lawrence trump ck you ’ end
# 	predic:  hamilton’ prohibition undo turley service’ turley centrist turley accomplish
# 306:
# 	actual: blues hate crime in the chicago obama created end
# 	predic:  flashback ‘for preserve service’ unbeaten turley turley accomplish turley
# 307:
# 	actual: start timeline how britain got to brexit end
# 	predic:  tancredo matter’s sostok hamilton’ turley sostok flashback strickland aol
# 308:
# 	actual: responds to north korean missile launch with restraint end
# 	predic:  rasmussen carolina serve serve unlock hampshire iggy undo yorker
# 309:
# 	actual: after boom room’ suit bias persists for women end
# 	predic:  hamilton’ ‘for ‘for sostok politico service’ sostok flashback ’classified’
# 310:
# 	actual: dylann roof found guilty in charleston church massacre end
# 	predic:  flashback turley sostok flashback sostok politico sims realize sostok
# 311:
# 	actual: start how trump could really ’drain the swamp end
# 	predic:  krauthammer service’ preserve aol service’ turley undo paramount usmc
# 312:
# 	actual: key moments and more from trump’s news conference end
# 	predic:  hamilton’ flourished semite semite sostok whoopi turley sostok krauthammer
# 313:
# 	actual: gives putin hand in u s proxy war end
# 	predic:  flashback york’s ampt yorkers ampt yorker hamilton’ accomplish uw
# 314:
# 	actual: thompson wins women’s 100m gold at rio 2016 end
# 	predic:  whoopi sostok hamilton’ ‘for turley sostok politico arranged service’
# 315:
# 	actual: saved by heart from nfl player who died end
# 	predic:  politico service’ sostok politico excoriates service’ sostok flashback service’
# 316:
# 	actual: start the dnc in 140 characters or less end
# 	predic:  politico stances detect turley beleaguered sostok flashback ’satanist’ aol
# 317:
# 	actual: jewish leaders slam un secretary general for statement end
# 	predic:  rasmussen jong clinton’ york’s sostok flashback sostok whoopi sostok
# 318:
# 	actual: plans to testify surprised senate intelligence panel members end
# 	predic:  krauthammer recruit undo fy afdi turley install service’ brakes
# 319:
# 	actual: did affect donald trump’s voice at the debate end
# 	predic:  krauthammer sostok hamilton’ sostok hamilton’ firebombing ‘for service’ turley
# 320:
# 	actual: start coming soon superhero universe for girls end
# 	predic:  tancredo ‘for ’classified’ sostok krauthammer ’classified’ turley service’ aol
# 321:
# 	actual: to leave more troops than planned in afghanistan end
# ...
# 	predic:  tancredo koppel preserve sostok flashback ‘for service’ aol turley
# 893:
# 	actual: start the fight for dzhokhar tsarnaev’s life end
# 	predic:  rasmussen sostok krauthammer ‘for service’ sostok flashback junks quo’
# 894:
# 	actual: start study children of parents more likely end
# 	predic:  flashback sostok whoopi service’ turley 1995 ‘for election’s sostok
# 895:
# 	actual: start should we be scared of butter end
# 	predic:  hamilton’ service’ turley ‘for ‘for resettle sostok tancredo turley
# 896:
# 	actual: start brazil protests call for dilma impeachment end
# 	predic:  flashback interaction recruit sostok tancredo service’ turley turley service’
# 897:
# 	actual: of wall street trading floor says it all end
# 	predic:  whoopi turley service’ service’ ‘for service’ service’ service’ turley
# 898:
# 	actual: of an entire movement to restore the constitution’ end
# 	predic:  krauthammer solve undo afdi interfere recruit sostok flashback ’hurting
# 899:
# 	actual: world’s wealth is going to just 62 people end
# 	predic:  whoopi ‘for leans impose ‘for turley understanding understanding toby
# 900:
# 	actual: an islam problem not an islamic terror problem end
# 	predic:  krauthammer old’s sostok hamilton’ turley sostok flashback sostok hamilton’
# 901:
# 	actual: start south sudan fast facts end
# 	predic:  hamilton’ ‘for 1999 codes ’pathological ’classified’ krauthammer stevie ’classified’
# 902:
# 	actual: blame israel for downing egyptair plane in plot end
# 	predic:  flashback newsman undo sostok gunpoint sostok tancredo turley service’
# 903:
# 	actual: start survey millennials believe economy is failing them end
# 	predic:  whoopi leans ’secret ‘for turley service’ sostok flashback service’
# 904:
# 	actual: cutting edge tech by classic gameplay is fun end
# 	predic:  flashback francis impose sostok tancredo ‘for ‘for cincinnati resettle
# 905:
# 	actual: americans ’more confident’ in donald trump post election end
# 	predic:  flashback ’important’ preserve turley turley afdi yorkers radicalisation firebombing
# 906:
# 	actual: start watch trump jeb spar over eminent domain end
# 	predic:  whoopi turley recruit sostok whoopi korea least sostok krauthammer
# 907:
# 	actual: hollywood media mercilessly mock kellyanne conway’s trump inauguration end
# 	predic:  flashback francis solve briefing service’ service’ service’ turley frame
# 908:
# 	actual: trump is suddenly sounding like general election candidate end
# 	predic:  hamilton’ turley terminate assimilate anglo kent kent orleans anglo
# 909:
# 	actual: sketch of possible witness in queens jogger’s killing end
# 	predic:  krauthammer service’ preserve service’ orleans flashback service’ york’s hampshire
# 910:
# 	actual: start putin is planning to the kgb end
# 	predic:  hamilton’ leans solve service’ frame strickland service’ tran tran
# 911:
# 	actual: start the great american sleep recession end
# 	predic:  krauthammer service’ sostok hamilton’ turley krauthammer aol flashback sostok
# 912:
# 	actual: don’t kick out anti abortion dems from party end
# 	predic:  delingpole
# 913:
# 	actual: start fast facts end
# 	predic:  flashback lite undo turley ’tone machado fabricating turley virgil
# 914:
# 	actual: dershowitz most serious charge ever against us president end
# 	predic:  krauthammer improperly detect fy paramount 2025 2025 preserve retain
# 915:
# 	actual: court sends transgender case back to lower court end
# 	predic:  whoopi blunder ampt service’ aol turley turley sostok hamilton’
# 916:
# 	actual: to believe’ hillary would do anything ’intentionally wrong’ end
# 	predic:  whoopi bernardino undo pen turley afdi sostok krauthammer sostok
# 917:
# 	actual: australian college baseball player to be re sentenced end
# 	predic:  tancredo sostok whoopi sostok flashback turley undo chemistry’ recruit
# 918:
# 	actual: armstrong trump is ’f cking hitler man ’ end
# 	predic:  tancredo newsman atone solve turley turley logging logging kent
# 919:
# 	actual: hours after brutal attack by following brexit row end
# 	predic:  hamilton’ sostok flashback service’ service’ turley service’ sostok flashback
# 920:
# 	actual: people are trying to pin it on me end
# 	predic:  whoopi turley undo turley sostok hamilton’ ‘for paramount strickland
# 921:
# 	actual: stabbed at the university of texas in austin end
# 	predic:  tancredo sostok whoopi turley undo service’ turley turley krauthammer
# 922:
# 	actual: state showdown cruz sanders projected to win wisconsin end
# 	predic:  whoopi country’ knowingly assimilate fracture fracture 2025 sostok hamilton’
# 923:
# 	actual: hugh laurie rips republicans trump at golden globes end
# 	predic:  whoopi newsman service’ service’ centrist service’ centrist centrist afdi
# 924:
# 	actual: panelist ’the public should not trust police officers’ end
# 	predic:  hamilton’ 84 solve sostok flashback ’desperate thrones’ york’s zealand
# 925:
# 	actual: obama to carry her across the finish line end
# 	predic:  flashback sostok krauthammer sostok hamilton’ sostok whoopi sostok whoopi
# 926:
# 	actual: jet of flying too close to american plane end
# 	predic:  whoopi orleans ampt francisco hampshire hampshire hampshire hampshire punish
# 927:
# 	actual: start meet the new from end
# 	predic:  whoopi ‘for sostok hamilton’ excoriates service’ sostok flashback firebombing
# 928:
# 	actual: e the 124 year old software start up end
# 	predic:  whoopi turley krauthammer turley service’ sostok whoopi sostok krauthammer
# 929:
# 	actual: start simon clarifies comments on ’childish’ sci fi end
# 	predic:  whoopi ‘for matter’s service’ service’ turley service’ aol turley
# 930:
# 	actual: start bill clinton mocks people’ who oppose hillary end
# 	predic:  whoopi negotiate recruit service’ ces 1999 service’ turley krauthammer
# 931:
# 	actual: start airport shutdown embarrassing end
# 	predic:  rasmussen ‘for sostok krauthammer ’classified’ firebombing service’ sostok flashback
# 932:
# 	actual: cases in california up 54 in one week end
# 	predic:  krauthammer ‘for service’ turley sostok rasmussen ‘for sostok punish
# 933:
# 	actual: americans need to do better job their privilege end
# 	predic:  politico undo ensure survive’ touchscreen bowl ampt sostok whoopi
# 934:
# 	actual: short’ just viciously slammed the wall street journal end
# 	predic:  tancredo prohibition ‘for turley service’ service’ service’ aol sostok
# 935:
# 	actual: day fading elsewhere still ritual on colorado ranch end
# 	predic:  flashback ‘for ‘for service’ turley sostok rasmussen ‘for sostok
# 936:
# 	actual: start issa hillary clinton’s is in question’ end
# 	predic:  whoopi undo fiasco semite undo bowl 87 2025 sostok
# 937:
# 	actual: thousands evacuated as wildfire threatens celebrity homes in end
# 	predic:  tancredo sostok rasmussen sostok flashback backward’ undo service’ firebombing
# 938:
# 	actual: before the wall migrants find the u s end
# 	predic:  tancredo sostok politico 1995 ‘for sostok hamilton’ sostok whoopi
# 939:
# 	actual: start a with scales that like computer simulation end
# 	predic:  krauthammer ‘for service’ ’classified’ excoriates turley rasmussen schiff turley
# 940:
# 	actual: start chicago police doj report details excessive force end
# 	predic:  krauthammer turley undo ‘for turley krauthammer turley rasmussen snl’
# 941:
# 	actual: passed out in cockpit accused of being drunk end
# 	predic:  rasmussen newsman bullsh bullsh francisco rasmussen krauthammer solve centrist
# 942:
# 	actual: electoral college set to make trump’s win official end
# 	predic:  whoopi sostok krauthammer service’ sostok recruit turley undo sostok
# 943:
# 	actual: voice for many victims of illegal alien criminals end
# 	predic:  flashback ’nuclear undo turley turley sostok whoopi carolina service’
# 944:
# 	actual: date men who earn less than they do end
# 	predic:  tancredo interaction sostok krauthammer turley sostok whoopi turley whoopi
# 945:
# 	actual: gunmen hold up border city currency exchange store end
# 	predic:  flashback newsman recruit sostok politico excoriates politico delingpole sostok
# 946:
# 	actual: in istanbul airport attack reflect city’s international character end
# 	predic:  whoopi sostok politico krauthammer musk turley rasmussen politico krauthammer
# 947:
# 	actual: comes out against house gop health care bill end
# 	predic:  delingpole ‘for undo ’delegitimize’ mapping turley sostok rasmussen krauthammer
# 948:
# 	actual: room’ talk athletes push back on trump remark end
# 	predic:  hamilton’ flourished ces turley service’ firebombing aol strickland realize
# 949:
# 	actual: poll of polls clinton leads trump by points end
# 	predic:  whoopi undo turley service’ anglo orleans homestretch bottom’ ’beauty’
# 950:
# 	actual: election seen as test of tolerance for indonesia end
# 	predic:  tancredo ’important’ service’ service’ turley levi leans sostok flashback
# 951:
# 	actual: autistic man who tweets pictures after copyright complaints end
# 	predic:  hamilton’ ‘for ‘for sostok flashback ’desperate impose impose turley
# 952:
# 	actual: start hispanics in the us fast facts end
# 	predic:  hamilton’ alps recruit service’ sostok krauthammer jameis turley rasmussen
# 953:
# 	actual: office hur’ bombs ’suicide squad’ stays on top end
# 	predic:  hamilton’ service’ leans reassure service’ leans sostok whoopi ’classified’
# 954:
# 	actual: sources dennis hastert cover up for sexual misconduct end
# 	predic:  tancredo interaction solve turley service’ turley service’ ’bimbo’ aol
# 955:
# 	actual: bike riders beat up driver on california freeway end
# 	predic:  whoopi ‘for ‘for turley turley sostok whoopi ‘for service’
# 956:
# 	actual: start french inmate unlocks others fire set end
# 	predic:  rasmussen ‘for terminate ‘for sostok rasmussen snl’ francisco flashback
# 957:
# 	actual: retail have one thing in common they’re ugly end
# 	predic:  tancredo sostok hamilton’ prohibition ‘for ‘for service’ turley toby
# 958:
# 	actual: hillary clinton calls 31 million breitbart readers ’racist’ end
# 	predic:  flashback ’important’ undo service’ sostok whoopi service’ decorate decorate
# 959:
# 	actual: start cnn 10 february 14 2017 end
# 	predic:  politico anglo turley krauthammer turley krauthammer satirical turley flashback
# 960:
# 	actual: republican party megyn kelly titanic your wednesday briefing end
# 	predic:  whoopi ucf preserve marry preserve dunham ’low ‘contested’ preserve
# 961:
# 	actual: ’loves his family and he loves this country’ end
# 	predic:  politico marry solve ‘for assimilate ’pervasive bottom’ paramount 1999
# 962:
# 	actual: thaad antimissile system in south korea after tests end
# 	predic:  flashback york’s detect detect zealand yorkers nytimes cincinnati yorker
# 963:
# 	actual: start police move in on arena bomber’s ’network end
# 	predic:  hamilton’ ‘for ’unconstitutional ‘for ‘for sostok flashback service’ disavow
# 964:
# 	actual: chair hurling brawl breaks out in nyc seafood end
# 	predic:  krauthammer turley cede ‘for service’ sostok whoopi sostok politico
# 965:
# 	actual: home wi fi and it’s on sale today end
# 	predic:  hamilton’ sostok tancredo service’ service’ sostok flashback sostok whoopi
# 966:
# 	actual: start explores violence youth with twist end
# 	predic:  krauthammer ‘for turley sostok flashback turley infect turley rasmussen
# 967:
# 	actual: largest county to comply with trump’s sanctuary crackdown end
# 	predic:  rasmussen less’ recruit sostok tancredo sostok delingpole strickland firebombing
# 968:
# 	actual: start gary johnson on charitable donations ’almost end
# 	predic:  delingpole
# 969:
# 	actual: trump administration orders tougher screening of visa applicants end
# 	predic:  hamilton’ 84 solve turley definitely bottom’ service’ turley turley
# 970:
# 	actual: start pokemon go takes state department briefing end
# 	predic:  rasmussen ‘for ‘for disparage ‘for turley jamie hampshire reassure
# 971:
# 	actual: national charged for alleged assault on ice agent end
# 	predic:  rasmussen sostok flashback sostok tancredo turley delingpole turley negotiate
# 972:
# 	actual: start tightened security worldwide for new year’s eve end
# 	predic:  whoopi ‘for election’s ’perfectly ‘for pantsuit sostok rasmussen snl’
# 973:
# 	actual: for bill de blasio sounds sour note for end
# 	predic:  krauthammer ‘for ‘for sostok tancredo turley aol service’ kent
# 974:
# 	actual: obama calls out at campaign stop for clinton end
# 	predic:  whoopi turley recruit service’ service’ centrist usmc usmc aol
# 975:
# 	actual: start trump’s campaign style lost in end
# 	predic:  whoopi hydrogen solve sostok whoopi least leans flashback turley
# 976:
# 	actual: savages family of refugee rape victim on facebook end
# 	predic:  flashback ‘for ‘for ‘for sostok flashback physically ’forget turley
# 977:
# 	actual: south korea election moon jae in declared winner end
# 	predic:  delingpole preserve 84 service’ riveter service’ ruhle ‘mr thrones’
# 978:
# 	actual: start a night with bill cosby it’s complicated end
# 	predic:  flashback ’isn’t semite sostok tancredo excoriates krauthammer usmc retain
# 979:
# 	actual: bud an for equity reaches hall of fame end
# 	predic:  flashback newsman ‘for sostok whoopi service’ service’ sostok tancredo
# 980:
# 	actual: claims media is ’poisoning the minds’ of voters end
# 	predic:  krauthammer turley preserve cede turley terminate yorkers service’ service’
# 981:
# 	actual: big lead for hillary clinton but it’s shrinking end
# 	predic:  whoopi ’cowardly’ undo sostok krauthammer turley verify thrones’ thrones’
# 982:
# 	actual: john mccain fundraiser arrested in major drug bust end
# 	predic:  hamilton’ orleans reassure orleans york’s york’s zealand nordic service’
# 983:
# 	actual: start rick empty diner strategy end
# 	predic:  tancredo newsman solve matter’s ’delegitimize’ satirical brakes justify sostok
# 984:
# 	actual: needs hackers to keep up with tech companies end
# 	predic:  tancredo lite ‘for sostok hamilton’ sostok rasmussen ’classified’ service’
# 985:
# 	actual: start sjws clash over ’transphobic’ hashtag end
# 	predic:  whoopi jong clinton’ onion turley sostok flashback ’important’ accelerate
# 986:
# 	actual: start trump got ’bad from the super bowl end
# 	predic:  tancredo sostok flashback circuited’ semite impose ‘for service’ turley
# 987:
# 	actual: lin verdict exposes the of china’s legal system end
# 	predic:  hamilton’ ‘are turley service’ bottom’ sostok rasmussen sostok krauthammer
# 988:
# 	actual: ok with attacking trump because establishment’s ’about power’ end
# 	predic:  flashback matter’s atone semite service’ korea sostok flashback airspace
# 989:
# 	actual: clinton warns against treating donald trump as candidate end
# 	predic:  flashback service’ undo fracture sunderland paramount anglo kent thrones’
# 990:
# 	actual: equality’ marchers push for progress on lgbt rights end
# 	predic:  tancredo trusts ’illegal’ aol turley ‘for aol aol aol
# 991:
# 	actual: start fans call to after import ban end
# 	predic:  hamilton’ sostok flashback ’classified’ ’classified’ ‘for service’ sostok hamilton’
# 992:
# 	actual: border patrol agents bust child sexual predator murderer end
# 	predic:  krauthammer sostok krauthammer dunham turley krauthammer service’ falwell sostok
# 993:
# 	actual: clarke hillary is ’a straight up cop hater’ end
# 	predic:  whoopi wiretapped undo sostok delingpole leans sostok whoopi service’
# 994:
# 	actual: start how tom cruise from moving plane end
# 	predic:  whoopi newsman deeply sostok whoopi turley hamilton’ sostok hamilton’
# 995:
# 	actual: start what shot 41 amazing sports photos end
# 	predic:  whoopi valley turley sostok rasmussen sostok rasmussen whoopi turley
# 996:
# 	actual: theresa may rejects second scottish referendum before brexit end
# 	predic:  tancredo jong sostok rasmussen supporter’s service’ korea zucked understanding
# 997:
# 	actual: possible hack of democratic party staffer cell phones end
# 	predic:  flashback bernardino politico undo savor 2025 roadkill fy sostok
# 998:
# 	actual: are buzzing about the race for the cabinet end
# 	predic:  krauthammer ‘for undo terminate turley turley terminate bottom’ sostok
# 999:
# 	actual: start cnn 10 january 11 2017 end
# 	predic:  rasmussen ‘for sostok flashback strickland sostok rasmussen ’transgender’ infect
# 1000:
# 	actual: jones trump ’a super predator running for president’ end
# 	predic:  whoopi preserve solve matter’s atone 2025 service’ turley anglo
